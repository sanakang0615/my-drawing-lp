# %%
import os

# 폴더 경로 지정
folder_path = "/Users/sanakang/Desktop/my-website/public/drawings"

# 폴더 내 모든 파일 이름 가져오기
file_names = os.listdir(folder_path)

# 파일 이름 출력
for file_name in file_names:
    print(file_name)
# Out:
# ichizu.jpg
# fake plastic trees.jpg
# coffee and tv.jpg
# fun for me.jpg
# sex and candy.jpg
# this picture.jpg
# music of night.jpg
# take five.jpg
# rhcp_american_ghost_dance.png
# book.jpg
# in my place.jpg
# The King of Romance.jpg
# avant-garde kim.jpg
# love buzz.jpg
# itan na star.jpg
# beautiful thing.jpg
# fly.jpg
# Weird Fishes Arpeggi.jpg
# sleep.jpg
# tokimeki.jpg
# summer2.jpg
# follow you.jpg
# zelda.jpg
# the great pretender.jpg
# island in the sun.jpg
# blue.jpg
# sweet marie.jpg
# whiteboard.jpg
# damn.jpg
# no life.jpg
# good good night.jpg
# mother tongue.jpg
# fluke.jpg
# dry flower.jpg
# chlorine.jpg
# trippy.jpg
# Love is all.jpg
# when you sleep.jpeg
# semiautomatic.jpg
# the less I know is better.jpg
# napori.jpg
# nodeul.jpg
# stay here.jpg
# hollywood.jpg
# shining.jpg
# surprise.jpg
# feburary.jpg
# sansu station.jpg
# pure morning.jpg
# mouse.jpg
# the secret of hard rock.jpg
# plastic love.jpg
# pending machine.jpg
# black star.jpg
# ukiyoe.jpg
# ...
